# %%
import pandas as pd

# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa0 in position 0: invalid start byte
df = pd.read_csv("Minimum Wage Data.csv", encoding="latin")
df.to_csv("minwage.csv", encoding="utf-8")
df = pd.read_csv("minwage.csv")
df.head()
# Out:
#    Unnamed: 0  Year       State           Table_Data Footnote  High.Value  \
# 0           0  1968     Alabama                  ...      NaN     0.00000
# 1           1  1968      Alaska                 2.10      NaN     2.10000
# 2           2  1968     Arizona  18.72 - 26.40/wk(b)      (b)     0.66000
# 3           3  1968    Arkansas          1.25/day(b)      (b)     0.15625
# 4           4  1968  California              1.65(b)      (b)     1.65000
#
#    Low.Value  CPI.Average  High.2018  Low.2018
# 0    0.00000    34.783333       0.00      0.00
# 1    2.10000    34.783333      15.12     15.12
# 2    0.46800    34.783333       4.75      3.37
# 3    0.15625    34.783333       1.12      1.12
# 4    1.65000    34.783333      11.88     11.88

# %%
gb = df.groupby("State")
gb.get_group("Alabama").set_index("Year").head()
# Out:
#       Unnamed: 0    State Table_Data Footnote  High.Value  Low.Value  \
# Year
# 1968           0  Alabama        ...      NaN         0.0        0.0
# 1969          55  Alabama        ...      NaN         0.0        0.0
# 1970         110  Alabama        ...      NaN         0.0        0.0
# 1971         165  Alabama        ...      NaN         0.0        0.0
# 1972         220  Alabama        ...      NaN         0.0        0.0
#
#       CPI.Average  High.2018  Low.2018
# Year
# 1968    34.783333        0.0       0.0
# 1969    36.683333        0.0       0.0
# 1970    38.825000        0.0       0.0
# 1971    40.491667        0.0       0.0
# 1972    41.816667        0.0       0.0

# %%
act_min_wage = pd.DataFrame()

for name, group in df.groupby("State"):
    if act_min_wage.empty:
        act_min_wage = group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name})
    else:
        act_min_wage = act_min_wage.join(group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name}))

act_min_wage.head()
# Out:
#       Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1968      0.0   15.12     3.37      1.12       11.88      7.20        10.08
# 1969      0.0   14.33     3.19      1.07       11.26      6.83         9.56
# 1970      0.0   13.54     3.02      7.09       10.64      6.45        10.32
# 1971      0.0   12.99     2.89      6.80       10.20      6.18         9.89
# 1972      0.0   12.57     2.80      7.19        9.88      5.99        11.08
#
#       Delaware  District of Columbia  Federal (FLSA)  ...  Tennessee  Texas  \
# Year                                                  ...
# 1968      9.00                  9.00            8.28  ...        0.0   0.00
# 1969      8.53                  8.53            7.85  ...        0.0   0.00
# 1970      8.06                 10.32            8.38  ...        0.0   0.00
# 1971      7.73                  9.89            8.04  ...        0.0   0.00
# 1972      9.58                  9.58            9.58  ...        0.0   8.38
#
#       U.S. Virgin Islands  Utah  Vermont  Virginia  Washington  West Virginia  \
# Year
# 1968                  NaN  7.20    10.08       0.0       11.52           7.20
# 1969                  NaN  6.83     9.56       0.0       10.92           6.83
# 1970                  NaN  6.45    10.32       0.0       10.32           6.45
# 1971                  NaN  6.18     9.89       0.0        9.89           6.18
# 1972                  NaN  7.19     9.58       0.0        9.58           7.19
#
#       Wisconsin  Wyoming
# Year
# 1968       9.00     8.64
# 1969       8.53     8.19
# 1970       8.38     8.38
# 1971       8.04     8.04
# 1972       8.68     8.98
#
# [5 rows x 55 columns]

# %%
act_min_wage.describe()
# Out:
#        Alabama     Alaska    Arizona   Arkansas  California   Colorado  \
# count     50.0  50.000000  50.000000  50.000000   50.000000  50.000000
# mean       0.0   9.583800   2.316200   6.781600    8.632800   6.389800
# std        0.0   1.845176   3.474504   1.341223    1.187508   1.521052
# min        0.0   7.380000   0.000000   1.070000    6.420000   3.840000
# 25%        0.0   8.252500   0.000000   6.522500    7.695000   5.072500
# 50%        0.0   8.890000   0.000000   6.920000    8.670000   6.375000
# 75%        0.0  10.492500   3.147500   7.290000    9.307500   7.677500
# max        0.0  15.120000  10.220000   8.680000   11.880000   9.500000
#
#        Connecticut   Delaware  District of Columbia  Federal (FLSA)  ...  \
# count    50.000000  50.000000             50.000000       50.000000  ...
# mean      8.823600   7.498800              8.343200        7.773200  ...
# std       1.023613   1.265436              1.476133        0.887354  ...
# min       6.820000   4.410000              5.510000        6.220000  ...
# 25%       7.865000   7.015000              7.097500        7.172500  ...
# 50%       9.075000   7.845000              8.510000        7.655000  ...
# 75%       9.455000   8.327500              9.140000        8.242500  ...
# max      11.080000   9.580000             12.000000       10.010000  ...
#
#        Tennessee      Texas  U.S. Virgin Islands       Utah    Vermont  \
# count       50.0  50.000000            39.000000  50.000000  50.000000
# mean         0.0   5.541200             6.643590   6.836600   8.657400
# std          0.0   2.202229             1.590176   0.819367   0.984647
# min          0.0   0.000000             4.390000   4.790000   6.800000
# 25%          0.0   4.762500             5.105000   6.317500   7.800000
# 50%          0.0   6.070000             6.770000   6.930000   8.885000
# 75%          0.0   7.105000             7.830000   7.470000   9.372500
# max          0.0   8.380000            10.010000   8.330000  10.320000
#
#         Virginia  Washington  West Virginia  Wisconsin    Wyoming
# count  50.000000   50.000000      50.000000  50.000000  50.000000
# mean    5.897400    8.301800       7.166400   7.694200   5.149200
# std     2.726151    1.868613       0.793673   0.762675   1.998928
# min     0.000000    4.410000       5.580000   6.420000   2.260000
# 25%     5.892500    7.227500       6.630000   7.107500   3.270000
# 50%     6.855000    9.055000       7.075000   7.580000   5.445000
# 75%     7.620000    9.672500       7.612500   8.145000   6.607500
# max     8.800000   11.520000       9.130000   9.660000   8.980000
#
# [8 rows x 55 columns]

# %%
act_min_wage.corr().head()
# Out:
#             Alabama    Alaska   Arizona  Arkansas  California  Colorado  \
# Alabama         NaN       NaN       NaN       NaN         NaN       NaN
# Alaska          NaN  1.000000  0.018638 -0.377934    0.717653 -0.129332
# Arizona         NaN  0.018638  1.000000  0.089395    0.498994  0.742527
# Arkansas        NaN -0.377934  0.089395  1.000000   -0.234367  0.135749
# California      NaN  0.717653  0.498994 -0.234367    1.000000  0.483313
#
#             Connecticut  Delaware  District of Columbia  Federal (FLSA)  ...  \
# Alabama             NaN       NaN                   NaN             NaN  ...
# Alaska         0.680886  0.258997              0.321785        0.637679  ...
# Arizona        0.458163  0.429836              0.590848       -0.049914  ...
# Arkansas       0.047580  0.016125              0.266889        0.117245  ...
# California     0.876215  0.479197              0.596865        0.371966  ...
#
#             Tennessee     Texas  U.S. Virgin Islands      Utah   Vermont  \
# Alabama           NaN       NaN                  NaN       NaN       NaN
# Alaska            NaN -0.522472             0.277016 -0.020462  0.663558
# Arizona           NaN  0.369900            -0.758607  0.439344  0.517960
# Arkansas          NaN  0.503242            -0.204485  0.194680  0.087429
# California        NaN -0.239533            -0.417782  0.392898  0.877922
#
#             Virginia  Washington  West Virginia  Wisconsin   Wyoming
# Alabama          NaN         NaN            NaN        NaN       NaN
# Alaska     -0.601640    0.411593       0.044814   0.702570  0.727932
# Arizona     0.047405    0.587975       0.584596   0.131588  0.346528
# Arkansas    0.582192   -0.072343       0.420819   0.000470 -0.250592
# California -0.326364    0.754085       0.371765   0.584067  0.722617
#
# [5 rows x 55 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  Year       State           Table_Data Footnote  High.Value  \
# 0           0  1968     Alabama                  ...      NaN     0.00000
# 1           1  1968      Alaska                 2.10      NaN     2.10000
# 2           2  1968     Arizona  18.72 - 26.40/wk(b)      (b)     0.66000
# 3           3  1968    Arkansas          1.25/day(b)      (b)     0.15625
# 4           4  1968  California              1.65(b)      (b)     1.65000
#
#    Low.Value  CPI.Average  High.2018  Low.2018
# 0    0.00000    34.783333       0.00      0.00
# 1    2.10000    34.783333      15.12     15.12
# 2    0.46800    34.783333       4.75      3.37
# 3    0.15625    34.783333       1.12      1.12
# 4    1.65000    34.783333      11.88     11.88

# %%
issue_df = df[df['Low.2018']==0]
issue_df.head()
# Out:
#     Unnamed: 0  Year     State Table_Data Footnote  High.Value  Low.Value  \
# 0            0  1968   Alabama        ...      NaN         0.0        0.0
# 10          10  1968   Florida        ...      NaN         0.0        0.0
# 11          11  1968   Georgia        ...      NaN         0.0        0.0
# 15          15  1968  Illinois        ...      NaN         0.0        0.0
# 17          17  1968      Iowa        ...      NaN         0.0        0.0
#
#     CPI.Average  High.2018  Low.2018
# 0     34.783333        0.0       0.0
# 10    34.783333        0.0       0.0
# 11    34.783333        0.0       0.0
# 15    34.783333        0.0       0.0
# 17    34.783333        0.0       0.0

# %%
issue_df["State"].unique()
# Out:
# array(['Alabama', 'Florida', 'Georgia', 'Illinois', 'Iowa', 'Kansas',
#        'Louisiana', 'Mississippi', 'Missouri', 'Montana',
#        'South Carolina', 'Tennessee', 'Texas', 'Virginia', 'Arizona'],
#       dtype=object)

# %%
import numpy as np

act_min_wage.replace(0,np.NaN).dropna(axis=1).corr().head()
# Out:
#                Alaska  Arkansas  California  Colorado  Connecticut  Delaware  \
# Alaska       1.000000 -0.377934    0.717653 -0.129332     0.680886  0.258997
# Arkansas    -0.377934  1.000000   -0.234367  0.135749     0.047580  0.016125
# California   0.717653 -0.234367    1.000000  0.483313     0.876215  0.479197
# Colorado    -0.129332  0.135749    0.483313  1.000000     0.402020  0.566304
# Connecticut  0.680886  0.047580    0.876215  0.402020     1.000000  0.552613
#
#              District of Columbia  Federal (FLSA)      Guam    Hawaii  ...  \
# Alaska                   0.321785        0.637679  0.787915  0.672620  ...
# Arkansas                 0.266889        0.117245  0.039593  0.204801  ...
# California               0.596865        0.371966  0.492052  0.519241  ...
# Colorado                 0.673371       -0.232035 -0.192616  0.069800  ...
# Connecticut              0.652488        0.487750  0.632073  0.621503  ...
#
#              Pennsylvania  Puerto Rico  Rhode Island  South Dakota      Utah  \
# Alaska           0.610814    -0.038118      0.652353     -0.326316 -0.020462
# Arkansas         0.159923     0.232186      0.003498      0.800116  0.194680
# California       0.429061     0.512712      0.780916     -0.036787  0.392898
# Colorado        -0.136195     0.657364      0.429852      0.399137  0.622330
# Connecticut      0.531769     0.626712      0.802485      0.105707  0.302538
#
#               Vermont  Washington  West Virginia  Wisconsin   Wyoming
# Alaska       0.663558    0.411593       0.044814   0.702570  0.727932
# Arkansas     0.087429   -0.072343       0.420819   0.000470 -0.250592
# California   0.877922    0.754085       0.371765   0.584067  0.722617
# Colorado     0.448485    0.612637       0.533623   0.011501  0.130053
# Connecticut  0.898469    0.715691       0.400099   0.585790  0.814971
#
# [5 rows x 39 columns]

# %%
min_wage_corr = act_min_wage.replace(0,np.NaN).dropna(axis=1).corr().head()

for problem in issue_df['State'].unique():
    if problem in min_wage_corr.columns:
        print("We're missing something here...")

# %%
grouped_issues = issue_df.groupby("State")

grouped_issues.get_group("Alabama")['Low.2018'].sum()
# Out:
# 0.0

# %%
for state, date in grouped_issues:
    if date['Low.2018'].sum() != 0.0:
        print("We missed something!")

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("minwage.csv")

act_min_wage = pd.DataFrame()

for name, group in df.groupby("State"):
    if act_min_wage.empty:
        act_min_wage = group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name})
    else:
        act_min_wage = act_min_wage.join(group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name}))

act_min_wage.head()

min_wage_corr = act_min_wage.replace(0, np.NaN).dropna(axis=1).corr()

min_wage_corr.head()
# Out:
#                Alaska  Arkansas  California  Colorado  Connecticut  Delaware  \
# Alaska       1.000000 -0.377934    0.717653 -0.129332     0.680886  0.258997
# Arkansas    -0.377934  1.000000   -0.234367  0.135749     0.047580  0.016125
# California   0.717653 -0.234367    1.000000  0.483313     0.876215  0.479197
# Colorado    -0.129332  0.135749    0.483313  1.000000     0.402020  0.566304
# Connecticut  0.680886  0.047580    0.876215  0.402020     1.000000  0.552613
#
#              District of Columbia  Federal (FLSA)      Guam    Hawaii  ...  \
# Alaska                   0.321785        0.637679  0.787915  0.672620  ...
# Arkansas                 0.266889        0.117245  0.039593  0.204801  ...
# California               0.596865        0.371966  0.492052  0.519241  ...
# Colorado                 0.673371       -0.232035 -0.192616  0.069800  ...
# Connecticut              0.652488        0.487750  0.632073  0.621503  ...
#
#              Pennsylvania  Puerto Rico  Rhode Island  South Dakota      Utah  \
# Alaska           0.610814    -0.038118      0.652353     -0.326316 -0.020462
# Arkansas         0.159923     0.232186      0.003498      0.800116  0.194680
# California       0.429061     0.512712      0.780916     -0.036787  0.392898
# Colorado        -0.136195     0.657364      0.429852      0.399137  0.622330
# Connecticut      0.531769     0.626712      0.802485      0.105707  0.302538
#
#               Vermont  Washington  West Virginia  Wisconsin   Wyoming
# Alaska       0.663558    0.411593       0.044814   0.702570  0.727932
# Arkansas     0.087429   -0.072343       0.420819   0.000470 -0.250592
# California   0.877922    0.754085       0.371765   0.584067  0.722617
# Colorado     0.448485    0.612637       0.533623   0.011501  0.130053
# Connecticut  0.898469    0.715691       0.400099   0.585790  0.814971
#
# [5 rows x 39 columns]

# %%
pip install matplot
# Out:
# Requirement already satisfied: matplot in c:\python39\lib\site-packages (0.1.9)
# Requirement already satisfied: matplotlib>=3.1.1 in c:\python39\lib\site-packages (from matplot) (3.4.3)
# Requirement already satisfied: pyloco>=0.0.134 in c:\python39\lib\site-packages (from matplot) (0.0.139)
# Requirement already satisfied: numpy>=1.16 in c:\python39\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.21.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python39\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\python39\lib\site-packages (from matplotlib>=3.1.1->matplot) (8.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python39\lib\site-packages (from matplotlib>=3.1.1->matplot) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python39\lib\site-packages (from matplotlib>=3.1.1->matplot) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\python39\lib\site-packages (from matplotlib>=3.1.1->matplot) (0.10.0)
# Requirement already satisfied: six in c:\python39\lib\site-packages (from cycler>=0.10->matplotlib>=3.1.1->matplot) (1.16.0)
# Requirement already satisfied: SimpleWebSocketServer in c:\python39\lib\site-packages (from pyloco>=0.0.134->matplot) (0.1.1)
# Requirement already satisfied: websocket-client in c:\python39\lib\site-packages (from pyloco>=0.0.134->matplot) (1.2.1)
# Requirement already satisfied: typing in c:\python39\lib\site-packages (from pyloco>=0.0.134->matplot) (3.7.4.3)
# Requirement already satisfied: ushlex in c:\python39\lib\site-packages (from pyloco>=0.0.134->matplot) (0.99.1)
# Requirement already satisfied: twine in c:\python39\lib\site-packages (from pyloco>=0.0.134->matplot) (3.4.2)
# Requirement already satisfied: pkginfo>=1.4.2 in c:\python39\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.7.1)
# Requirement already satisfied: rfc3986>=1.4.0 in c:\python39\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.5.0)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in c:\python39\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (0.9.1)
# Requirement already satisfied: keyring>=15.1 in c:\python39\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (23.2.1)
# Requirement already satisfied: tqdm>=4.14 in c:\python39\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (4.62.3)
# Requirement already satisfied: colorama>=0.4.3 in c:\python39\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (0.4.4)
# Requirement already satisfied: readme-renderer>=21.0 in c:\python39\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (30.0)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\python39\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (4.8.1)
# Requirement already satisfied: requests>=2.20 in c:\python39\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.26.0)
# Requirement already satisfied: zipp>=0.5 in c:\python39\lib\site-packages (from importlib-metadata>=3.6->twine->pyloco>=0.0.134->matplot) (3.6.0)
# Requirement already satisfied: pywin32-ctypes!=0.1.0,!=0.1.1 in c:\python39\lib\site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (0.2.0)
# Requirement already satisfied: docutils>=0.13.1 in c:\python39\lib\site-packages (from readme-renderer>=21.0->twine->pyloco>=0.0.134->matplot) (0.17.1)
# Requirement already satisfied: Pygments>=2.5.1 in c:\python39\lib\site-packages (from readme-renderer>=21.0->twine->pyloco>=0.0.134->matplot) (2.10.0)
# Requirement already satisfied: bleach>=2.1.0 in c:\python39\lib\site-packages (from readme-renderer>=21.0->twine->pyloco>=0.0.134->matplot) (4.1.0)
# Requirement already satisfied: packaging in c:\python39\lib\site-packages (from bleach>=2.1.0->readme-renderer>=21.0->twine->pyloco>=0.0.134->matplot) (21.0)
# Requirement already satisfied: webencodings in c:\python39\lib\site-packages (from bleach>=2.1.0->readme-renderer>=21.0->twine->pyloco>=0.0.134->matplot) (0.5.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\python39\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python39\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\python39\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python39\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (1.26.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

plt.matshow(min_wage_corr)

# %%
labels = [c[:2] for c in min_wage_corr.columns]  # get abbv state names.

fig = plt.figure(figsize=(12,12))  # figure so we can add axis
ax = fig.add_subplot(111)  # define axis, so we can modify
ax.matshow(min_wage_corr, cmap=plt.cm.RdYlGn)  # display the matrix
ax.set_xticks(np.arange(len(labels)))  # show them all!
ax.set_yticks(np.arange(len(labels)))  # show them all!
ax.set_xticklabels(labels)  # set to be the abbv (vs useless #)
ax.set_yticklabels(labels)  # set to be the abbv (vs useless #)

plt.show()

# %%
pip install html5lib bs4
# Out:
# Requirement already satisfied: html5lib in c:\python39\lib\site-packages (1.1)
# Requirement already satisfied: bs4 in c:\python39\lib\site-packages (0.0.1)
# Requirement already satisfied: webencodings in c:\python39\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\python39\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in c:\python39\lib\site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\python39\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
 pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\python39\lib\site-packages (4.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

web = requests.get("https://www.infoplease.com/state-abbreviations-and-state-postal-codes")
dfs = pd.read_html(web.text)


import pandas as pd

# https://www.infoplease.com/state-abbreviations-and-state-postal-codes

dfs = pd.read_html("https://www.infoplease.com/state-abbreviations-and-state-postal-codes")

# %%
for df in dfs:
    print(df.head())
# Out:
#   State/District Abbreviation Postal Code
# 0        Alabama         Ala.          AL
# 1         Alaska       Alaska          AK
# 2        Arizona        Ariz.          AZ
# 3       Arkansas         Ark.          AR
# 4     California       Calif.          CA
#         Territory/Associate Abbreviation Postal Code
# 0            American Samoa          NaN          AS
# 1                      Guam         Guam          GU
# 2          Marshall Islands          NaN          MH
# 3                Micronesia          NaN          FM
# 4  Northern Mariana Islands          NaN          MP

# %%
state_abbv = dfs[0]
state_abbv.head()
# Out:
#   State/District Abbreviation Postal Code
# 0        Alabama         Ala.          AL
# 1         Alaska       Alaska          AK
# 2        Arizona        Ariz.          AZ
# 3       Arkansas         Ark.          AR
# 4     California       Calif.          CA

# %%
state_abbv.to_csv("state_abbv.csv",index=False)

# %%
state_abbv = pd.read_csv('state_abbv.csv',index_col=0)
state_abbv.head()
# Out:
#                Abbreviation Postal Code
# State/District
# Alabama                Ala.          AL
# Alaska               Alaska          AK
# Arizona               Ariz.          AZ
# Arkansas               Ark.          AR
# California           Calif.          CA

# %%
abbv_dict = state_abbv[["Postal Code"]].to_dict()

abbv_dict = abbv_dict["Postal Code"]
abbv_dict
# Out:
# {'Alabama': 'AL',
#  'Alaska': 'AK',
#  'Arizona': 'AZ',
#  'Arkansas': 'AR',
#  'California': 'CA',
#  'Colorado': 'CO',
#  'Connecticut': 'CT',
#  'Delaware': 'DE',
#  'District of Columbia': 'DC',
#  'Florida': 'FL',
#  'Georgia': 'GA',
#  'Hawaii': 'HI',
#  'Idaho': 'ID',
#  'Illinois': 'IL',
#  'Indiana': 'IN',
#  'Iowa': 'IA',
#  'Kansas': 'KS',
#  'Kentucky': 'KY',
#  'Louisiana': 'LA',
#  'Maine': 'ME',
#  'Maryland': 'MD',
#  'Massachusetts': 'MA',
#  'Michigan': 'MI',
#  'Minnesota': 'MN',
#  'Mississippi': 'MS',
#  'Missouri': 'MO',
#  'Montana': 'MT',
#  'Nebraska': 'NE',
#  'Nevada': 'NV',
#  'New Hampshire': 'NH',
#  'New Jersey': 'NJ',
#  'New Mexico': 'NM',
#  'New York': 'NY',
#  'North Carolina': 'NC',
#  'North Dakota': 'ND',
#  'Ohio': 'OH',
#  'Oklahoma': 'OK',
#  'Oregon': 'OR',
#  'Pennsylvania': 'PA',
#  'Rhode Island': 'RI',
#  'South Carolina': 'SC',
#  'South Dakota': 'SD',
#  'Tennessee': 'TN',
#  'Texas': 'TX',
#  'Utah': 'UT',
#  'Vermont': 'VT',
#  'Virginia': 'VA',
#  'Washington': 'WA',
#  'West Virginia': 'WV',
#  'Wisconsin': 'WI',
#  'Wyoming': 'WY'}

# %%
labels = [abbv_dict[c] for c in min_wage_corr.columns]  # get abbv state names.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15172/1867733507.py in <module>
# ----> 1 labels = [abbv_dict[c] for c in min_wage_corr.columns]  # get abbv state names.
#
# ~\AppData\Local\Temp/ipykernel_15172/1867733507.py in <listcomp>(.0)
# ----> 1 labels = [abbv_dict[c] for c in min_wage_corr.columns]  # get abbv state names.
#
# KeyError: 'Federal (FLSA)'

# %%
abbv_dict['Federal (FLSA)'] = "FLSA"
labels = [abbv_dict[c] for c in min_wage_corr.columns]  # get abbv state names.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15172/2207567099.py in <module>
#       1 abbv_dict['Federal (FLSA)'] = "FLSA"
# ----> 2 labels = [abbv_dict[c] for c in min_wage_corr.columns]  # get abbv state names.
#
# ~\AppData\Local\Temp/ipykernel_15172/2207567099.py in <listcomp>(.0)
#       1 abbv_dict['Federal (FLSA)'] = "FLSA"
# ----> 2 labels = [abbv_dict[c] for c in min_wage_corr.columns]  # get abbv state names.
#
# KeyError: 'Guam'

# %%
abbv_dict['Guam'] = "GU"
abbv_dict['Puerto Rico'] = "PR"
labels = [abbv_dict[c] for c in min_wage_corr.columns]  # get abbv state names.

# %%
fig = plt.figure(figsize=(12,12))  # figure so we can add axis
ax = fig.add_subplot(111)  # define axis, so we can modify
ax.matshow(min_wage_corr, cmap=plt.cm.RdYlGn)  # display the matrix
ax.set_xticks(np.arange(len(labels)))  # show them all!
ax.set_yticks(np.arange(len(labels)))  # show them all!
ax.set_xticklabels(labels)  # set to be the abbv (vs useless #)
ax.set_yticklabels(labels)  # set to be the abbv (vs useless #)

plt.show()
